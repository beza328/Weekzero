# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
region1 = pd.read_csv('sierraleone-bumbuna.csv')

# %%
region1
# Out:
#                Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb     RH   WS  WSgust  \
# 0       2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.1  0.0     0.0
# 1       2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 2       2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 3       2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9   99.3  0.0     0.0
# 4       2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.3  0.0     0.0
# ...                  ...  ...  ...  ...   ...   ...   ...    ...  ...     ...
# 525595  2022-10-29 23:56 -1.6 -0.1 -2.9   0.0   0.0  24.0  100.0  0.0     0.0
# 525596  2022-10-29 23:57 -1.7 -0.1 -3.0   0.0   0.0  24.0  100.0  0.0     0.0
# 525597  2022-10-29 23:58 -1.7 -0.1 -3.1   0.0   0.0  24.0  100.0  0.0     0.0
# 525598  2022-10-29 23:59 -1.7 -0.2 -3.3   0.0   0.0  23.9  100.0  0.0     0.0
# 525599  2022-10-30 00:00 -1.7 -0.1 -3.4   0.0   0.0  23.9  100.0  0.0     0.0
#
# ...

# %%
import seaborn as sns

# %%
region1.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# ...

# %%
region1.shape
# Out:
# (525600, 19)

# %%
region1.index
# Out:
# RangeIndex(start=0, stop=525600, step=1)

# %%
region1.columns
# Out:
# Index(['Timestamp', 'GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'Tamb', 'RH', 'WS',
#        'WSgust', 'WSstdev', 'WD', 'WDstdev', 'BP', 'Cleaning', 'Precipitation',
#        'TModA', 'TModB', 'Comments'],
#       dtype='object')

# %%
region1.dtypes
# Out:
# Timestamp         object
# GHI              float64
# DNI              float64
# DHI              float64
# ModA             float64
# ModB             float64
# Tamb             float64
# RH               float64
# WS               float64
# WSgust           float64
# WSstdev          float64
# WD               float64
# WDstdev          float64
# BP                 int64
# Cleaning           int64
# Precipitation    float64
# TModA            float64
# TModB            float64
# Comments         float64
# dtype: object

# %%
print("Missing values:\n", region1.isnull().sum())
# Out:
# Missing values:
#  Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
region1.drop_duplicates(inplace=True)

# %%
print("\nCleaned Data:")
print(region1)
# Out:
# Cleaned Data:
#                Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb     RH   WS  WSgust  \
# 0       2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.1  0.0     0.0
# 1       2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 2       2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 3       2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9   99.3  0.0     0.0
# 4       2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.3  0.0     0.0
# ...                  ...  ...  ...  ...   ...   ...   ...    ...  ...     ...
# 525595  2022-10-29 23:56 -1.6 -0.1 -2.9   0.0   0.0  24.0  100.0  0.0     0.0
# 525596  2022-10-29 23:57 -1.7 -0.1 -3.0   0.0   0.0  24.0  100.0  0.0     0.0
# 525597  2022-10-29 23:58 -1.7 -0.1 -3.1   0.0   0.0  24.0  100.0  0.0     0.0
# 525598  2022-10-29 23:59 -1.7 -0.2 -3.3   0.0   0.0  23.9  100.0  0.0     0.0
# 525599  2022-10-30 00:00 -1.7 -0.1 -3.4   0.0   0.0  23.9  100.0  0.0     0.0
#
# ...

# %%
descriptive_stats = region1.describe()
print("Descriptive Statistics:")
print(descriptive_stats)
# Out:
# Descriptive Statistics:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# ...

# %%
data_types = region1.dtypes
print("\nData Types:\n" , data_types)
# Out:
# Data Types:
#  Timestamp         object
# GHI              float64
# DNI              float64
# DHI              float64
# ModA             float64
# ModB             float64
# Tamb             float64
# RH               float64
# WS               float64
# WSgust           float64
# WSstdev          float64
# WD               float64
# WDstdev          float64
# BP                 int64
# Cleaning           int64
# Precipitation    float64
# TModA            float64
# TModB            float64
# Comments         float64
# dtype: object

# %%
region1["date"] = pd.to_datetime(region1['Timestamp'])
region1.set_index('date', inplace=True)

# %%
monthly_data = region1[['GHI', 'DNI', 'DHI', 'Tamb']].resample('M').mean()
# Out:
# C:\Users\mama\AppData\Local\Temp\ipykernel_7480\1773505043.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = region1[['GHI', 'DNI', 'DHI', 'Tamb']].resample('M').mean()

# %%
plt.figure(figsize=(14, 8))

plt.plot(monthly_data['GHI'], label='GHI', marker='o')
plt.plot(monthly_data['DNI'], label='DNI', marker='o')
plt.plot(monthly_data['DHI'], label='DHI', marker='o')
plt.plot(monthly_data['Tamb'],label='Tamb', marker='o')

plt.title('Monthly Paterns of GHI, DNI, DHI, and Tamb Over Time')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
cleaning_impact = region1.groupby('Cleaning')[['ModA', 'ModB']].mean()
print(cleaning_impact)
# Out:
#                 ModA        ModB
# Cleaning
# 0         206.578599  198.038150
# 1         273.309252  277.231102

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))


for cleaning_status in region1['Cleaning'].unique():
    subset = region1[region1['Cleaning'] == cleaning_status]
    plt.plot(subset.index, subset['ModA'], label=f'ModA - {cleaning_status}', marker='o', alpha=0.7)
    plt.plot(subset.index, subset['ModB'], label=f'ModB - {cleaning_status}', marker='o', alpha=0.7)


plt.title('Impact of Cleaning on Sensor Readings Over Time')
plt.xlabel('Date')
plt.ylabel('Sensor Readings')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mama\AppData\Local\Temp\ipykernel_7480\2304153732.py:18: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()

# %%
correlation_data = region1[['GHI', 'DNI', 'DHI', 'TModA', 'TModB']]

# Calculate the correlation matrix
correlation_matrix = correlation_data.corr()
print(correlation_matrix)
# Out:
#             GHI       DNI       DHI     TModA     TModB
# GHI    1.000000  0.869108  0.865815  0.923092  0.912260
# DNI    0.869108  1.000000  0.536710  0.816449  0.808194
# DHI    0.865815  0.536710  1.000000  0.808479  0.807551
# TModA  0.923092  0.816449  0.808479  1.000000  0.993228
# TModB  0.912260  0.808194  0.807551  0.993228  1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('Correlation Heatmap between Solar Radiation and Temperature Measures')
plt.show()

# %%
sns.pairplot(correlation_data)
plt.suptitle('Pair Plot of Solar Radiation and Temperature Measures', y=1.02)
plt.show()

# %%
wind_irradiance_data = region1[['GHI', 'DNI', 'DHI', 'WS', 'WSgust', 'WD']]

pd.plotting.scatter_matrix(wind_irradiance_data, figsize=(12, 12), diagonal='kde')
plt.suptitle('Scatter Matrix of Wind Conditions and Solar Irradiance', y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[59], line 3
#       1 wind_irradiance_data = region1[['GHI', 'DNI', 'DHI', 'WS', 'WSgust', 'WD']]
# ----> 3 pd.plotting.scatter_matrix(wind_irradiance_data, figsize=(12, 12), diagonal='kde')
#       4 plt.suptitle('Scatter Matrix of Wind Conditions and Solar Irradiance', y=1.02)
#       5 plt.show()
#
# File c:\Users\mama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_misc.py:220, in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     168 """
#     169 Draw a matrix of scatter plots.
#     170
#    (...)
#     217           dtype=object)
#     218 """
#     219 plot_backend = _get_plot_backend("matplotlib")
# --> 220 return plot_backend.scatter_matrix(
#     221     frame=frame,
#     222     alpha=alpha,
# ...
